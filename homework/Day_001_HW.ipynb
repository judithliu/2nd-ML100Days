# %% [markdown]
# ## 作業1：
# #### 請上 Kaggle, 在 Competitions 或 Dataset 中找一組競賽或資料並寫下：
# #### 資料來源: Google Landmark Recognition 2019
# #### 1.	你選的這組資料為何重要
#     使用者可透過google的地標識別，協助他們歸類跟整理相簿，照片也可自動辨別拍攝的地標。
# #### 2. 資料從何而來 (tips: 譬如提供者是誰、以什麼方式蒐集)
#     Google提供的 Google Landmarks Dataset v2。
# #### 3. 蒐集而來的資料型態為何
#     CSV結構化的資料檔跟非結構化的照片檔。
# #### 4. 這組資料想解決的問題如何評估
#     使用 Global Average Precision (GAP)；$ GAP = \frac{1}{M}\sum_{i=1}^N P(i) rel(i) $
#     where:
#
#     $ N $ is the total number of predictions returned by the system, across all queries
#     $ M $ is the total number of queries with at least one landmark from the training set visible in it (note that some queries may not depict landmarks)
#     $ P(i) $ is the precision at rank $ i $
#     $ rel(i) $ denotes the relevance of prediciton $ i $: it’s 1 if the $ i $-th prediction is correct, and 0 otherwise
#
# ## 作業2：
# #### 想像你經營一個自由載客車隊，你希望能透過數據分析以提升業績，請你思考並描述你如何規劃整體的分析/解決方案：
# #### 1.	核心問題為何 (tips：如何定義 「提升業績 & 你的假設」)
#     提升業績:舊客人的回客率+新客人的增加率
#     (1) 乘車的地緣性(方便性)
#     (2) 乘車價格
#     (3) 司機服務品質
#  #### 2. 資料從何而來 (tips：哪些資料可能會對你想問的問題產生影響 & 資料如何蒐集)
#     (1)問卷
#     (2)叫車紀錄
#     (3)消費紀錄
# #### 3. 蒐集而來的資料型態為何
#     結構化數據
# #### 4. 你要回答的問題，其如何評估 (tips：你的假設如何驗證)
#     利用回歸分析探討上訴因素是否與提升業績有關聯。
# ###

# %% [markdown]
# ## 練習時間
# #### 請寫一個函式用來計算 Mean Square Error
# $ MSE = \frac{1}{n}\sum_{i=1}^{n}{(Y_i - \hat{Y}_i)^2} $
#
# ### Hint: [如何取平方](https://googoodesign.gitbooks.io/-ezpython/unit-1.html)

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def mean_squared_error(y, yhat):
    """
    請完成這個 Function 後往下執行
    """
    ''' y 與 yhat 的資料型態為 numpy.ndarray '''
    
    n = len(y)
    mse = sum((y-yhat)**2)/n
    
    return mse

# %%
def mean_absolute_error(y, yhat):
    ''' y 與 yhat 的資料型態為 numpy.ndarray '''
    
    n=len(y)
    
    mae= sum(np.abs(y-yhat))/n
    
    return mae

# %%
w = 3
b = 0.5

x_lin = np.linspace(0, 100, 101)

y = (x_lin + np.random.randn(101) * 5) * w + b

plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

# %%
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

# %%
# 執行 Function, 確認有沒有正常執行
MSE = mean_squared_error(y, y_hat)
MAE = mean_absolute_error(y, y_hat)
print("The Mean squared error is %.3f" % (MSE))
print("The Mean absolute error is %.3f" % (MAE))
# Out:
# The Mean squared error is 270.420
# The Mean absolute error is 13.517
